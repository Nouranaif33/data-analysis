# %% [markdown]
# <a href="https://colab.research.google.com/github/Nouranaif33/data-analysis/blob/main/Untitled14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler
import matplotlib.pyplot as plt




train_df = pd.read_csv("/content/train.csv",sep =";")
test_df = pd.read_csv("//content/test.csv", sep =";")
train_df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome   y
# 0  unknown    5   may       261         1     -1         0  unknown  no
# 1  unknown    5   may       151         1     -1         0  unknown  no
# 2  unknown    5   may        76         1     -1         0  unknown  no
# 3  unknown    5   may        92         1     -1         0  unknown  no
# 4  unknown    5   may       198         1     -1         0  unknown  no

# %%
train_df.shape
# Out:
# (45211, 17)

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  y          45211 non-null  object
# dtypes: int64(7), object(10)
# memory usage: 5.9+ MB

# %%
train_df.describe()
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous
# count  45211.000000  45211.000000
# mean      40.197828      0.580323
# std      100.128746      2.303441
# min       -1.000000      0.000000
# 25%       -1.000000      0.000000
# 50%       -1.000000      0.000000
# ...

# %%
train_df.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 45206    False
# 45207    False
# 45208    False
# 45209    False
# 45210    False
# Length: 45211, dtype: bool

# %%
train_df.sort_values(["age", "duration"], ascending=True).head()
# Out:
#        age      job marital  education default  balance housing loan  \
# 42954   18  student  single    unknown      no      108      no   no
# 41222   18  student  single    unknown      no       35      no   no
# 40736   18  student  single    primary      no     1944      no   no
# 41273   18  student  single    unknown      no        3      no   no
# 41252   18  student  single  secondary      no        5      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome    y
# 42954   cellular    9   feb        92         1    183         1  success  yes
# 41222  telephone   21   aug       104         2     -1         0  unknown   no
# 40736  telephone   10   aug       122         3     -1         0  unknown   no
# 41273   cellular   25   aug       130         2     -1         0  unknown  yes
# 41252   cellular   24   aug       143         2     -1         0  unknown   no

# %%
train_df.isnull().sum()
# Out:
# age          0
# job          0
# marital      0
# education    0
# default      0
# balance      0
# housing      0
# loan         0
# contact      0
# day          0
# month        0
# duration     0
# campaign     0
# pdays        0
# previous     0
# poutcome     0
# y            0
# dtype: int64

# %%
columns = train_df.columns.values
print(columns)
# Out:
# ['age' 'job' 'marital' 'education' 'default' 'balance' 'housing' 'loan'
#  'contact' 'day' 'month' 'duration' 'campaign' 'pdays' 'previous'
#  'poutcome' 'y']

# %%
train_df.groupby("marital")["y"].value_counts()
# Out:
# marital   y
# divorced  no      4585
#           yes      622
# married   no     24459
#           yes     2755
# single    no     10878
#           yes     1912
# Name: y, dtype: int64

# %%
train_df.job.value_counts()
# Out:
# blue-collar      9732
# management       9458
# technician       7597
# admin.           5171
# services         4154
# retired          2264
# self-employed    1579
# entrepreneur     1487
# unemployed       1303
# housemaid        1240
# student           938
# unknown           288
# Name: job, dtype: int64

# %%
sns.countplot(x="education",data=train_df, hue = "y")
plt.title("Education type vs Count")
# Out:
# Text(0.5, 1.0, 'Education type vs Count')
